# %%
# find the endpoint of Gemini API
from google import genai

client=genai.Client(api_key="AIzaSyABADVXn25w_NkSkRbTGuUXw6Ec1l1QBnc")


# send requests/questions to Gemini
response = client.models.generate_content(
    model='gemini-2.0-flash-exp',
    contents='give a small response text to NLP use ase?')
print(response.text)
# Out:
# Okay, I understand you're asking for a short response about Natural Language Processing (NLP) use cases. Here are a few options, depending on the angle you want:
#
# **General Response:**
#
# * "NLP powers a wide range of applications, from chatbots and machine translation to sentiment analysis and information extraction."
#
# **Response highlighting a specific use case:**
#
# * "Sentiment analysis using NLP helps businesses understand customer opinions from social media and reviews."
#
# **Response emphasizing the growing importance:**
#
# * "NLP is increasingly vital for businesses to process and understand the vast amounts of textual data available today."

# %%
# find the endpoint of Gemini API
from google import genai

client=genai.Client(api_key="AIzaSyABADVXn25w_NkSkRbTGuUXw6Ec1l1QBnc")


# send requests/questions to Gemini
response = client.models.generate_content(
    model='gemini-2.0-flash-exp',
    contents='hi my name is mahesh.what is you name?')
#print(response.text)

import sys, time

for _ in response.text:
    sys.stdout.write(_)
    sys.stdout.flush()
    time.sleep(0.02)
# Out:
# It's nice to meet you, Mahesh! I don't have a name, as I am an AI assistant. You can just call me Bard.
